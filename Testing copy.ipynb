# %%
import pandas as pd
import numpy as np
import pickle
from pathlib import Path
import dill
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import TargetEncoder
import os
from helper_functions import *

# %%
df_test = load_data('test.csv')

# %%
id_test = df_test['Id']

# %%
df_test = drop_features(df_test, features_to_drop=['Alley','PoolQC','Fence','MiscFeature'])

# %%
df_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     1461          20       RH         80.0    11622   Pave      Reg
# 1     1462          20       RL         81.0    14267   Pave      IR1
# 2     1463          60       RL         74.0    13830   Pave      IR1
# 3     1464          60       RL         78.0     9978   Pave      IR1
# 4     1465         120       RL         43.0     5005   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# ...

# %%
df_test = clean_data(df_test, train=False)

# %%
df_test.isna().sum().sum()
# Out:
# np.int64(0)

# %%
# with open('encoders.pickle', 'rb') as f:
#     encoders = dill.load(f)

# %%
# encoders['target'].get_feature_names_out()

# %%
# with open('encode_data.pickle', 'rb') as f:
#     encode_data = dill.load(f)

Target_Encoding_list = ['MSZoning', 'Street', 'Utilities', 'LotConfig', 'Neighborhood', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'Foundation', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'Electrical', 'GarageType', 'SaleType']
Ordinal_Encoding_list= ['LotShape', 'LandContour', 'LandSlope', 'Condition1', 'Condition2', 'BldgType', 'ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'HeatingQC', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleCondition']


encoding_methods = {col: 'target' for col in Target_Encoding_list} 
encoding_methods.update({col: 'ordinal' for col in Ordinal_Encoding_list})

df_test = encode_data(df_test, encoding_methods , train=False, target=['SalePrice'])
# Out:
# {'target': TargetEncoder(), 'ordinal': OrdinalEncoder()}

# %%
df_test.CentralAir = np.where(df_test.CentralAir == 'N', 0, 1)

# %%
df_test
# Out:
#           Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0     1461.0        20.0       0.0         80.0  11622.0     0.0       3.0
# 1     1462.0        20.0       0.0         81.0  14267.0     0.0       0.0
# 2     1463.0        60.0       0.0         74.0  13830.0     0.0       0.0
# 3     1464.0        60.0       0.0         78.0   9978.0     0.0       0.0
# 4     1465.0       120.0       0.0         43.0   5005.0     0.0       0.0
# ...      ...         ...       ...          ...      ...     ...       ...
# 1454  2915.0       160.0       0.0         21.0   1936.0     0.0       3.0
# 1455  2916.0       160.0       0.0         21.0   1894.0     0.0       3.0
# 1456  2917.0        20.0       0.0        160.0  20000.0     0.0       3.0
# 1457  2918.0        85.0       0.0         62.0  10441.0     0.0       3.0
# 1458  2919.0        60.0       0.0         74.0   9627.0     0.0       3.0
#
# ...

# %%
with open('trained_fmodel1.pickle', 'rb') as f: 
    trained_model = dill.load(f)

    
with open('ffeature_list.pickle', 'rb') as f: 
    train_columns = dill.load(f)

df_test = df_test[train_columns] 
for col in train_columns: 
    df_test[col] = df_test[col].astype(float)


y_new_pred = predict_model(df_test, trained_model)
y_new_pred = y_new_pred.flatten()
# Out:
# Model's raw prediction: [-0.3473195  -0.45312375  0.35923624 ...  0.7247482  -0.9740355
#   1.021562  ]
# Predictions after inverse transform (if applicable):[144374.03 138480.38 191370.72 ... 221944.48 113007.89 250646.11]
# C:\Users\elige\AppData\Local\Temp\ipykernel_23828\2269390629.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test[col] = df_test[col].astype(float)
# C:\Users\elige\AppData\Local\Temp\ipykernel_23828\2269390629.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
y_new_pred
# Out:
# array([144374.03, 138480.38, 191370.72, ..., 221944.48, 113007.89,
#        250646.11], dtype=float32)

# %%
# Save predictions with corresponding IDs
model7_df = pd.DataFrame({'Id': id_test, 'SalePrice': y_new_pred})
model7_df.to_csv('prediction.csv', index=False)

# %%
results_df = df_test.copy() 
results_df['Id'] = id_test 
results_df['SalePrice'] = y_new_pred

# %%
# Save the combined DataFrame
results_df.to_csv('prediction_streamlit.csv', index=False)
